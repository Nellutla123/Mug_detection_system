# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="njGKnZI5Zu0r8aU8s9gQ")
project = rf.workspace("ai-devloper-17jru").project("mug_object_detection-yid5s")
version = project.version(1)
dataset = version.download("yolov11")
# Out:
# ...
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# ...
#   Using cached pillow-12.0.0-cp312-cp312-win_amd64.whl.metadata (9.0 kB)
# ...
#   Using cached python_dotenv-1.2.1-py3-none-any.whl.metadata (25 kB)
# ...
#   Using cached tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# ...
#   Using cached requests_toolbelt-1.0.0-py2.py3-none-any.whl.metadata (14 kB)
# ...
#      ---------------------------------------- 0.0/114.6 kB ? eta -:--:--
#      -------------------------------------- 114.6/114.6 kB 3.4 MB/s eta 0:00:00
# ...
#   Using cached pyparsing-3.2.5-py3-none-any.whl.metadata (5.0 kB)
# ...
#    ---------------------------------------- 0.0/89.9 kB ? eta -:--:--
#    ---------------------------------------- 89.9/89.9 kB 5.0 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/66.8 kB ? eta -:--:--
#    ---------------------------------------- 66.8/66.8 kB 1.8 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/38.8 MB ? eta -:--:--
# ...
